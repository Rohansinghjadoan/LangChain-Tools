# %%
# !pip install langchain_experimental
# Out:
# Collecting langchain_experimental
#   Downloading langchain_experimental-0.4.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in ./tools/lib/python3.12/site-packages (from langchain_experimental) (1.0.4)
# Requirement already satisfied: langchain-community<1.0.0,>=0.4.0 in ./tools/lib/python3.12/site-packages (from langchain_experimental) (0.4.1)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.4.43)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in ./tools/lib/python3.12/site-packages (from langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2.3.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./tools/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_experimental) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./tools/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_experimental) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./tools/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_experimental) (2.12.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./tools/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_experimental) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./tools/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./tools/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./tools/lib/python3.12/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./tools/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in ./tools/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./tools/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in ./tools/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./tools/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./tools/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./tools/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./tools/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_experimental) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./tools/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain_experimental) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./tools/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./tools/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./tools/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./tools/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./tools/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (2025.11.12)
# Requirement already satisfied: greenlet>=1 in ./tools/lib/python3.12/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (3.2.4)
# Requirement already satisfied: anyio in ./tools/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (4.11.0)
# Requirement already satisfied: httpcore==1.* in ./tools/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./tools/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./tools/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in ./tools/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain_experimental) (1.3.1)
# Downloading langchain_experimental-0.4.0-py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: langchain_experimental
# Successfully installed langchain_experimental-0.4.0

# %%
from langchain_community.tools import DuckDuckGoSearchRun
search_tool=DuckDuckGoSearchRun()
result = search_tool.run("What is the capital of France?")
print(result)
# Out:
# As the capital of France , Paris is the seat of France's national government. For the executive, the two chief officers each have their own official residences, which also serve as their offices. Learn why Paris is the capital of France and how it became a global city with a rich cultural heritage. Discover its geography, climate, population, landmarks, and industries. Jun 2, 2019 · Paris, the capital city of France , is one of the most famous and influential cities in the world. Located in the northern part of the country along the Seine River, Paris has been a center of culture, art, fashion, and intellectual thought for centuries. Nov 8, 2025 · Paris is the capital of France (French Republic), situated in the Western Europe subregion of Europe. In Paris, the currency used is Euro (€), which is the official currency used in France . Why is Paris the capital of France? Paris skyline, looking south from Montmartre. Paris is the capital of France , and therefore is the seat of France 's national government. For the executive, the two chief officers each have their own official residences, which also serve as their offices. What is the capital of France? As the capital of France, Paris is the seat of France's national government. For the executive, the two chief officers each have their own official residences, which also serve as their offices. The President of the French Republic resides at the Élysée Palace. Why is Paris known as the capital of the 19th century? Haussmann 's renovation of Paris , which created new boulevards, parks, and public works, gave birth to a modern city known as the "capital of the 19th century". Paris is a major railway, motorway, and air-transport hub; in 2024 Charles de Gaulle Airport was the EU's busiest airport. What is France known for? With a rich cultural history, a global presence in politics, economics, and the arts, and a strong role in the European Union, France is known for its contributions to world civilization . Paris, its capital, is not only the political center but also a cultural and financial epicenter with global influence. When did Soissons become the capital of France? Soissons was the capital of the Merovingian Kingdom of the Franks before Paris took over the role. King Clovis I established Soissons as the capital after his victory at the Battle of Soissons. In 508 , Clovis moved the capital to Paris, where it has remained ever since. 2. Rheims (Before 508 – 10th Century) When did Paris become a city? At the 1790 division (during the French Revolution) of France into communes, and again in 1834, Paris was a city only half its modern size, but in 1860 it annexed bordering communes, some entirely, to create the new administrative map of the twenty municipal arrondissements which are still active today. Paris is the capital city of France , situated on the River Seine, in northern France, at the heart of the Île-de-France region ("Région parisienne"). Jun 29, 2018 · Paris is the capital city of France , as well as the country's largest city. Paris is the capital city of France , situated on the River Seine, in northern France, at the heart of the Île-de-France region ("Région parisienne").

# %%
from langchain_community.tools import ShellTool
shell_tool = ShellTool()
result = shell_tool.run("ls")
print(result)
# Out:
# Executing command:
#  ls
# tools
# tools.ipynb
